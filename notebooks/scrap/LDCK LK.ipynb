# %%
# %matplotlib inline

from __future__ import division
import numpy as np
import menpo.io as mio
from menpo.image import Image
from menpo.feature import greyscale, normalize_norm, normalize_std, fast_dsift
from menpo.landmark import labeller, ibug_face_66
from menpo.visualize import visualize_images, print_dynamic, progress_bar_str
from menpofit.visualize import visualize_fitting_results
from alaborticcv2015.alignment import LKFitter, FilteredSSD, FilteredFourierSSD

# %% [markdown]
# # LDCK LK

# %% [markdown]
# Load training data:

# %%
images = []
for i in mio.import_images('/data/PhD/DataBases/faces/multipie/', verbose=True, 
                           max_images=66):
    i.crop_to_landmarks_proportion_inplace(0.5)
    i = i.rescale_landmarks_to_diagonal_range(200)
    labeller(i, 'PTS', ibug_face_66)
    lms = i.landmarks['ibug_face_66'].lms
    bb = lms.bounding_box()
    i.landmarks['bounding_box'] = bb
    images.append(i)
# Out:
# - Loading 66 assets: [====================] 100%

# %%
indices = [[j + k for j in range(3)] for k in range(6, 66, 15)]
indices = [j for k in indices for j in k] 

template = images[indices[0]]
test_images = [images[j] for j in indices][:3]

# %%
visualize_images(template)

# %%
visualize_images(test_images)

# %% [markdown]
# Create an LK fitter:

# %%
n_filters = range(4, 34, 4)
shapes = [s for s in range(3, 9, 2)]

# %% [markdown]
# Align:

# %%
n_rep = 50

for nf in [32]:
    for s in [5]:
        
        print '- Network {}, {}: '.format(nf, s)
        
        # load network
        file_name = ('/data/PhD/Models/alaborticcv2015/pca_net/pca_net_2_3_' 
                     + str(nf) 
                     + '_' 
                     + str(s)
                     + '.pkl.gz') 
        net = mio.import_pickle(file_name)
        
        kernel0 = net._compute_kernel(layer=0, ext_shape=(36, 36))
        kernel1 = net._compute_kernel(layer=2, ext_shape=(72, 72))
        
        # create LK fitter
        fitter = LKFitter(template,
                          group='bounding_box',
                          features=greyscale,
                          diagonal=100,
                          #scales=(1,),
                          residual_cls=FilteredFourierSSD,
                          kernel=[kernel0, kernel1])

        np.random.seed(seed=1)
        fitter_results = []
        for j, i in enumerate(test_images):
            string = '  - Image {}: '.format(j)

            frs = []
            for k in range(n_rep):
                print_dynamic('{}{}'.format(
                    string, progress_bar_str(k/n_rep, show_bar=True)))

                gt_s = i.landmarks['bounding_box'].lms
                s = fitter.perturb_shape(gt_s, noise_std=10)
                fr = fitter.fit(i, s, gt_shape=gt_s, max_iters=50)
                fr.downscale = 0.5
                frs.append(fr)

            fitter_results += frs

            errors = [fr.final_error() for fr in frs]    
            mean = np.mean(errors)
            median = np.median(errors)
            std = np.std(errors)

            print_dynamic(string + 
                          '\tmean={0:.4f}  median={1:.4f}  std={2:.4f}\n'.format(mean, median, std))

        errors = [fr.final_error() for fr in fitter_results]    
        mean = np.mean(errors)
        median = np.median(errors)
        std = np.std(errors)

        print_dynamic('  - Total:   ' + 
                      '\tmean={0:.4f}  median={1:.4f}  std={2:.4f}\n'.format(mean, median, std))
# Out:
# - Network 32, 5:
#   - Image 0: 	mean=0.0337  median=0.0053  std=0.0647
#   - Image 1: 	mean=0.0905  median=0.0714  std=0.0662
#   - Image 2: 	mean=0.0442  median=0.0134  std=0.0589
#   - Total:   	mean=0.0562  median=0.0142  std=0.0680

# %%
visualize_fitting_results(fitter_results)

# %%
visualize_fitting_results(fitter_results)

# %%
a = net.kernels_frequency(ext_shape=(36, 36))

# %%
visualize_images(a)

# %%
# Out:
# /data/PhD/multipie

# %%
from scipy.io.matlab import loadmat

# %%
aux = loadmat('/data/matlabdev/face_recognition_2011/data/myARCropped.mat')

# %%
i = Image(aux['example_imgs'][0][0])
i.landmarks['a'] = images[0].landmarks['PTS']
i.view_widget()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /data/pythondev/src/menpo/menpo/visualize/widgets/options.pyc in save_function(name)
#    1925                 paper_type=papertype_wid.value, format=format_wid.value,
#    1926                 transparent=transparent_wid.value,
# -> 1927                 pad_inches=pad_inches_wid.value, overwrite=overwrite.value)
#    1928             error_str.value = ''
#    1929         except ValueError as e:
#
# /data/pythondev/src/menpo/menpo/visualize/viewmatplotlib.pyc in save_figure(self, filename, format, dpi, face_colour, edge_colour, orientation, paper_type, transparent, pad_inches, overwrite)
#     118         # Use the export code so that we have a consistent interface
#     119         _export(save_fig_args, filename, self._extensions_map, format,
# --> 120                 overwrite=overwrite)
#     121
#     122     def save_figure_widget(self):
#
# /data/pythondev/src/menpo/menpo/io/output/base.pyc in _export(obj, fp, extensions_map, extension, overwrite)
#     176         fp = str(fp)  # cheeky conversion to string to reuse existing code
#     177     if isinstance(fp, basestring):
# --> 178         path_filepath = _validate_filepath(fp, extension, overwrite)
#     179
#     180         export_function = _extension_to_export_function(
#
# /data/pythondev/src/menpo/menpo/io/output/base.pyc in _validate_filepath(fp, extension, overwrite)
#     159     if extension is not None:
#     160         # use .suffixes[0] to handle compression suffixes correctly (see below)
# --> 161         filepath_suffix = path_filepath.suffixes[0]
#     162         # we couldn't find an exporter for all the suffixes (e.g .foo.bar)
#     163         # maybe the file stem has '.' in it? -> try again but this time just use the
#
# IndexError: list index out of range

# %%
aux['coords'][0]
# Out:
# array([ 65,  60, 235, 260], dtype=uint16)
